# %%
pip install --upgrade "protobuf>=3.20.3,<6"
# Out:
# Requirement already satisfied: protobuf<6,>=3.20.3 in c:\users\tejap\anaconda3\lib\site-packages (5.29.3)
# Collecting protobuf<6,>=3.20.3
#   Downloading protobuf-5.29.6-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Downloading protobuf-5.29.6-cp310-abi3-win_amd64.whl (435 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Successfully uninstalled protobuf-5.29.3
# Successfully installed protobuf-5.29.6
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.45.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.

# %%
pip install --upgrade tf-keras
# Out:
# Collecting tf-keras
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# INFO: pip is looking at multiple versions of tf-keras to determine which version is compatible with other requirements. This could take a while.
#   Downloading tf_keras-2.19.0-py3-none-any.whl.metadata (1.8 kB)
#   Downloading tf_keras-2.18.0-py3-none-any.whl.metadata (1.6 kB)
#   Downloading tf_keras-2.17.0-py3-none-any.whl.metadata (1.6 kB)
#   Downloading tf_keras-2.16.0-py3-none-any.whl.metadata (1.6 kB)
#   Downloading tf_keras-2.15.1-py3-none-any.whl.metadata (1.7 kB)
#   Downloading tf_keras-2.15.0-py3-none-any.whl.metadata (1.6 kB)
# Downloading tf_keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------ --------------------------- 0.5/1.7 MB 63.1 kB/s eta 0:00:19
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------ --------------------- 0.8/1.7 MB 63.0 kB/s eta 0:00:15
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------ --------------- 1.0/1.7 MB 66.1 kB/s eta 0:00:11
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------ --------- 1.3/1.7 MB 64.5 kB/s eta 0:00:07
#    ------------------------------------ --- 1.6/1.7 MB 64.2 kB/s eta 0:00:03
#    ------------------------------------ --- 1.6/1.7 MB 64.2 kB/s eta 0:00:03
#    ------------------------------------ --- 1.6/1.7 MB 64.2 kB/s eta 0:00:03
#    ------------------------------------ --- 1.6/1.7 MB 64.2 kB/s eta 0:00:03
#    ------------------------------------ --- 1.6/1.7 MB 64.2 kB/s eta 0:00:03
#    ---------------------------------------- 1.7/1.7 MB 67.4 kB/s  0:00:24
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.15.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\sanja\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
pip install --upgrade tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\sanja\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
# functonal modal(graph based, branching , merging, skip) , subclassed model - all different models


from tensorflow.keras.layers import Dense, Flatten
# conv2d, dropout, lstm, - one lego block - all different layers
# Dense(128, activation='relu')

# Load data
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Build model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Train
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=3, validation_data=(x_test, y_test))

# Evaluate
print("Test accuracy:", model.evaluate(x_test, y_test)[1])
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# c:\Users\tejap\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9279 - loss: 0.2540 - val_accuracy: 0.9620 - val_loss: 0.1330
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9660 - loss: 0.1127 - val_accuracy: 0.9709 - val_loss: 0.0955
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9761 - loss: 0.0781 - val_accuracy: 0.9734 - val_loss: 0.0822
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9734 - loss: 0.0822
# Test accuracy: 0.9733999967575073

# %%
import numpy as np

# Pick one test image
idx = 0
image = x_test[idx]

# Model prediction (returns probabilities for 0–9)
pred = model.predict(image.reshape(1, 28, 28))  

# Show predicted label
print("Predicted digit:", np.argmax(pred))
print("Actual digit:", y_test[idx])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Predicted digit: 7
# Actual digit: 7
